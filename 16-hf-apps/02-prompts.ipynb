# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
our_prompt = """
I love trips, and I have been to 6 countries. 
I plan to visit few more soon.

Can you create a post for tweet in 10 words for the above?
"""

# %%
llm.invoke(our_prompt)
# Out:
# AIMessage(content='Love trips! Explored 6 countries, more adventures coming soon.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ca27e-f565-7663-a6b5-bccea5c135c7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 237, 'total_tokens': 280, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 223}})

# %% [markdown]
# #### Prompt Template

# %%
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# ##### Using F-String

# %% [markdown]
# <h6><font color='green'>
# F-String is a Python feature that allows easy string formatting by placing variables inside curly braces within a string, making code more readable and efficient.
#
# <br>
# __Code:__
# <br>
# name = "Alice"
# <br>
# age = 25
# <br>
# message = f"My name is {name} and I am {age} years old."
# <br>
# print(message)
# <br><br>
# __Output:__
# <br>
# My name is Alice and I am 25 years old.
# <font></h6>

# %%
wordsCount=3
our_text = "I love trips, and I have been to 6 countries. I plan to visit few more soon."

# %%
our_prompt = f"""
{our_text}

Can you create a post for tweet in {wordsCount} words for the above?
"""

# %%
llm.invoke(our_prompt)
# Out:
# AIMessage(content='Wanderlust. More. Soon.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ca2db-f472-7363-8a1d-62c3f649b806-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 734, 'total_tokens': 774, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 726}})

# %% [markdown]
# ##### Using Prompt template

# %%
template = """
{our_text}

Can you create a post for tweet in {wordsCount} words for the above?
"""

# %%
prompt = PromptTemplate(
    template=template,
    input_variables=["our_text", "wordsCount"]
)

# %%
final_prompt = prompt.format(our_text=our_text, wordsCount=wordsCount)
final_prompt
# Out:
# '\nI love trips, and I have been to 6 countries. I plan to visit few more soon.\n\nCan you create a post for tweet in 3 words for the above?\n'

# %%
llm.invoke(final_prompt)
# Out:
# AIMessage(content='**Global Adventures Await.**', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ca2dd-cac3-7b10-b3c0-7d959c5942bd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 644, 'total_tokens': 684, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 638}})
