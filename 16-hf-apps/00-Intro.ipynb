# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace

# %%
llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.2",
    task="conversational"
)

# %%
query = "What is the capital of India?"
chat_model = ChatHuggingFace(llm=llm)
response = chat_model.invoke(query)

# %%
response
# Out:
# AIMessage(content=" The capital city of India is New Delhi. New Delhi is an city and a union territory of India containing its national capital Territory and the seat of all three branches of the Government of India. New Delhi is situated in the northern part of India, adjacent to the historic city of Old Delhi. It is the centre of politics, administration and the arts in India, and an important tourist destination in its own right.\n\nNew Delhi was planned by the British in the 1910s as the capital of the British Raj. The city was inaugurated on 13 February 1931 and was fully commissioned in 1947 after India's independence from British Rule. It is named after the ancient city of Indraprastha mentioned in the Indian epic Mahabharata, and the site of Indraprastha is believed to be in or around New Delhi.\n\nIndia, officially the Republic of India, is a country in South Asia. It is the second-most populous country, the seventh-largest country by land area and the most populous democracy in the world. Bounded by the Indian Ocean on the southern side, the Arabian Sea on the south-west, and the Bay of Bengal on the south-east, it shares land borders with Pakistan to the west; China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian subcontinent, India is located to the north of the equator. India is a federal constitutional republic governed under the Constitution of India, which was adopted in 1950. The Constitution of India, the world's lengthiest written constitution, coefficients India in a parliamentary system, where the President of India is the head of state and the Prime Minister of India is the head of government.\n\nIndia is a pluralistic, multicultural, and secular society. It is home to a diversity of wildlife in a variety of protected habitats, forty-six UNESCO World Heritage Sites, and seven natural and twenty-two artificial lakes. India ranks 139th in human development index, 112th in the economic freedom index, and 143rd in the gender inequality index. It is a developing country, but it has been identified as one of the next eleven economies that will shape the global economy in the 21st century. Indian economy is the world'", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 512, 'prompt_tokens': 15, 'total_tokens': 527}, 'model_name': 'mistralai/Mistral-7B-Instruct-v0.2', 'system_fingerprint': '', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--644a3ea5-1f2a-4293-b7bb-a29a971ce411-0', usage_metadata={'input_tokens': 15, 'output_tokens': 512, 'total_tokens': 527})

# %% [markdown]
# #### Using gemini

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
response = model.invoke(query)

# %%
response
# Out:
# AIMessage(content='The capital of India is **New Delhi**.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--8d7cbdcd-68ef-45c6-b392-210678e1e7e4-0', usage_metadata={'input_tokens': 8, 'output_tokens': 30, 'total_tokens': 38, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 21}})
