# %% [markdown]
# #### 🤗 HUGGING FACE

# %%
from pathlib import Path
from dotenv import load_dotenv

notebook_dir = Path.cwd()
notebook_dir
# Out:
# PosixPath('/Users/sabbha/Desktop/Landchain_LangGraph/krish_tut/LANGCHAIN_WS/01-BASICS')

# %%
dotenv_path = notebook_dir.parent / '.env'
dotenv_path
# Out:
# PosixPath('/Users/sabbha/Desktop/Landchain_LangGraph/krish_tut/LANGCHAIN_WS/.env')

# %%
load_dotenv(dotenv_path=dotenv_path)
# Out:
# True

# %%
import os
os.environ['HF_TOKEN' ]= os.getenv("HF_TOKEN")
